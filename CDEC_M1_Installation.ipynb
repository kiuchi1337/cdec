# %% [markdown]
# Die folgende Codezeile installiert alle Pakete, die für die Notebooks aus Modul 1 benötigt werden.

# %%
# %pip install folium geolibre geopy leafmap matplotlib numpy openeo rasterio rio-cogeo
# Out:
# ...
#
#    ------------- -------------------------- 1/3 [nbformat]
#    ------------- -------------------------- 1/3 [nbformat]
#    ------------- -------------------------- 1/3 [nbformat]
#    -------------------------- ------------- 2/3 [nbstripout]
#    ---------------------------------------- 3/3 [nbstripout]
#
# ...
# Note: you may need to restart the kernel to use updated packages.
